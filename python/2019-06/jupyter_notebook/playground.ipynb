# %%
a = 3

# %%
b = 2

# %%
# asdfasdf

# %% [markdown]
# # Jupyter-Notebook
#
# - Zelle auswerten mit Shift + Enter
# - Alle Zellen auswerten über runtime - Restart and run all

# %% [markdown]
# ## NumPy

# %%
import numpy as np

# %%
# Python - Listen (mit Verweisen auf andere Integer)
list_a = [1, 2]
list_b = [3, 4]

# %%
# NumPy - Array -
# Daten sind hierin enthalten, ohne auf Python-Integer
# zu verweisen
array_a = np.array(list_a, dtype="int8")
array_b = np.array(list_b, dtype="int8")

# %%
# Python
result = []
for i in range(2):
    result.append(list_a[i] + list_b[i])
print(result)
# Out:
# [4, 6]

# %%
array_a + array_b
# Out:
# array([4, 6], dtype=int8)

# %%
array_a.dtype
# Out:
# dtype('int8')

# %%
rolls = np.random.randint(1, 7, size=(10**7, 10))

# %%
rolls[0, 0]
# Out:
# 3

# %%
roll_sums = np.sum(rolls, axis=1)

# %%
np.mean(roll_sums)
# Out:
# 34.9987837

# %%
roll_sums.mean()
# Out:
# 34.9987837

# %%
prices = np.array([14.99, 4, 2, 4])

inventory = np.array([100, 20, 0, 30])

# %%
asset_value = np.sum(prices * inventory)
asset_value
# Out:
# 1699.0

# %%
asset_value = prices @ inventory
asset_value = prices.dot(inventory)

# %%
asset_value
# Out:
# 1699.0

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
roll_sums_series = pd.Series(roll_sums)
roll_sums_series.plot.hist(bins=60)

# %%
area = pd.Series({'CN': 9.6, 'RU': 17, 'US': 9.8})
population = pd.Series({'CN': 1386, 'RU': 144, 'US': 327})

# %%
area[0]
# Out:
# 9.6

# %%
area["CN"]
# Out:
# 9.6

# %%
countries = pd.DataFrame({
    'area': area,
    'population': population})

# %%
countries
# Out:
#     area  population
# CN   9.6        1386
# RU  17.0         144
# US   9.8         327

# %%
euribor = pd.read_csv(
    "https://datahub.io/core/euribor/r/euribor-12m-monthly.csv",
    index_col="date")

# %%
euribor
# Out:
#              rate maturity_level granularity
# date
# 1999-01-01  3.213            12m     monthly
# 1999-02-01  2.998            12m     monthly
# 1999-03-01  3.079            12m     monthly
# 1999-04-01  2.939            12m     monthly
# 1999-05-03  2.680            12m     monthly
# 1999-06-01  2.735            12m     monthly
# 1999-07-01  2.910            12m     monthly
# 1999-08-02  3.188            12m     monthly
# 1999-09-01  3.284            12m     monthly
# 1999-10-01  3.401            12m     monthly
# 1999-11-01  3.756            12m     monthly
# 1999-12-01  3.763            12m     monthly
# 2000-01-03  3.885            12m     monthly
# 2000-02-01  4.079            12m     monthly
# 2000-03-01  4.165            12m     monthly
# 2000-04-03  4.304            12m     monthly
# 2000-05-02  4.573            12m     monthly
# 2000-06-01  4.983            12m     monthly
# 2000-07-03  5.041            12m     monthly
# 2000-08-01  5.164            12m     monthly
# ...

# %%
iris = pd.read_csv(
    "http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",
    header=None,
    names=["sepal_length", "sepal_width", "petal_length",
           "petal_width", "name"],
)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            name
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %%
sp500 = pd.read_csv(
    "https://datahub.io/core/s-and-p-500/r/data.csv",
    index_col="Date")

# %%
exchange_rates = pd.read_csv(
    "https://datahub.io/core/us-euro-foreign-exchange-rate/r/monthly.csv",
    parse_dates=[1])

# %%
iris.iloc[:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width         name
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.iloc[0, [0, 2]]
# Out:
# sepal_length    5.1
# petal_length    1.4
# Name: 0, dtype: object

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'name'], dtype='object')

# %%
euribor.loc['2009-01-02']
# Out:
# rate                3.025
# maturity_level        12m
# granularity       monthly
# Name: 2009-01-02, dtype: object

# %%
euribor.loc['2009-01-01': '2009-12-31']
# Out:
#              rate maturity_level granularity
# date
# 2009-01-02  3.025            12m     monthly
# 2009-02-02  2.259            12m     monthly
# 2009-03-02  2.025            12m     monthly
# 2009-04-01  1.801            12m     monthly
# 2009-05-04  1.718            12m     monthly
# 2009-06-01  1.626            12m     monthly
# 2009-07-01  1.497            12m     monthly
# 2009-08-03  1.346            12m     monthly
# 2009-09-01  1.302            12m     monthly
# 2009-10-01  1.237            12m     monthly
# 2009-11-02  1.237            12m     monthly
# 2009-12-01  1.236            12m     monthly

# %%
euribor.loc[:, "rate"]
euribor["rate"]
euribor.rate
# Out:
# date
# 1999-01-01    3.213
# 1999-02-01    2.998
# 1999-03-01    3.079
# 1999-04-01    2.939
# 1999-05-03    2.680
# 1999-06-01    2.735
# 1999-07-01    2.910
# 1999-08-02    3.188
# 1999-09-01    3.284
# 1999-10-01    3.401
# 1999-11-01    3.756
# 1999-12-01    3.763
# 2000-01-03    3.885
# 2000-02-01    4.079
# 2000-03-01    4.165
# 2000-04-03    4.304
# 2000-05-02    4.573
# 2000-06-01    4.983
# 2000-07-03    5.041
# 2000-08-01    5.164
# 2000-09-01    5.261
# 2000-10-02    5.173
# 2000-11-01    5.272
# 2000-12-01    5.054
# 2001-01-02    4.692
# 2001-02-01    4.505
# 2001-03-01    4.532
# 2001-04-02    4.314
# 2001-05-02    4.728
# 2001-06-01    4.396
#               ...
# 2014-11-03    0.339
# 2014-12-01    0.330
# 2015-01-02    0.323
# 2015-02-02    0.271
# 2015-03-02    0.230
# 2015-04-01    0.196
# 2015-05-04    0.170
# 2015-06-01    0.161
# 2015-07-01    0.164
# 2015-08-03    0.166
# 2015-09-01    0.161
# 2015-10-01    0.140
# 2015-11-02    0.109
# 2015-12-01    0.045
# ...

# %%
euribor.loc[euribor.rate < 0].index
# Out:
# Index(['2016-03-01', '2016-04-01', '2016-05-02', '2016-06-01', '2016-07-01',
#        '2016-08-01', '2016-09-01', '2016-10-03', '2016-11-01', '2016-12-01',
#        '2017-01-02', '2017-02-01', '2017-03-01', '2017-04-03'],
#       dtype='object', name='date')

# %%
iris[iris.name == "Iris-setosa"]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width         name
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
euribor.plot()

# %%
a = iris.sepal_length.plot.bar()

# %%
a.figure.savefig('test.png')

# %%
sp500["SP500"].plot()

# %%
iris.plot.box()

# %%
iris.sepal_length.plot.hist(bins=30)

# %%
iris.loc[iris.name=="Iris-setosa"].plot.scatter(x="sepal_length", y="petal_length")

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(iris)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f958cb0d5c0>,
# ...
#       dtype=object)

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris["petal_ratio"] = iris.petal_length / iris.petal_width

# %%
iris
# Out:
#      sepal_length  sepal_width  ...            name  petal_ratio
# 0             5.1          3.5  ...     Iris-setosa     7.000000
# 1             4.9          3.0  ...     Iris-setosa     7.000000
# 2             4.7          3.2  ...     Iris-setosa     6.500000
# 3             4.6          3.1  ...     Iris-setosa     7.500000
# 4             5.0          3.6  ...     Iris-setosa     7.000000
# 5             5.4          3.9  ...     Iris-setosa     4.250000
# 6             4.6          3.4  ...     Iris-setosa     4.666667
# 7             5.0          3.4  ...     Iris-setosa     7.500000
# 8             4.4          2.9  ...     Iris-setosa     7.000000
# 9             4.9          3.1  ...     Iris-setosa    15.000000
# 10            5.4          3.7  ...     Iris-setosa     7.500000
# 11            4.8          3.4  ...     Iris-setosa     8.000000
# 12            4.8          3.0  ...     Iris-setosa    14.000000
# ...

# %%
petal_ratio = iris.petal_length / iris.petal_width

# %%
type(petal_ratio)
# Out:
# pandas.core.series.Series

# %%
derived_data = pd.DataFrame({"petal_ratio": petal_ratio})

# %%
derived_data
# Out:
#      petal_ratio
# 0       7.000000
# 1       7.000000
# 2       6.500000
# 3       7.500000
# 4       7.000000
# 5       4.250000
# 6       4.666667
# 7       7.500000
# 8       7.000000
# 9      15.000000
# 10      7.500000
# 11      8.000000
# 12     14.000000
# 13     11.000000
# 14      6.000000
# 15      3.750000
# 16      3.250000
# 17      4.666667
# 18      5.666667
# 19      5.000000
# 20      8.500000
# 21      3.750000
# 22      5.000000
# 23      3.400000
# 24      9.500000
# 25      8.000000
# 26      4.000000
# 27      7.500000
# 28      7.000000
# 29      8.000000
# ..           ...
# 120     2.478261
# 121     2.450000
# 122     3.350000
# 123     2.722222
# 124     2.714286
# 125     3.333333
# 126     2.666667
# 127     2.722222
# 128     2.666667
# 129     3.625000
# 130     3.210526
# 131     3.200000
# 132     2.545455
# 133     3.400000
# 134     4.000000
# 135     2.652174
# 136     2.333333
# 137     3.055556
# 138     2.666667
# 139     2.571429
# ...
