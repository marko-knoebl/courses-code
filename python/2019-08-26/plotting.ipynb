# %%
# Code von hier:

# Präsentation "Python & Data Science"
# Abschnitt "Daten importieren und exportieren"
# Slide "CSV importieren"

import pandas as pd

iris = pd.read_csv(
    "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",
    header=None,
    names=["sepal_length", "sepal_width", "petal_length",
           "petal_width", "name"])

# erste vier Spalten als NumPy-Array
iris_np = iris.to_numpy()[:, :4].astype("float16")

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 1, 2, 3])

y1 = x*2
y2 = x**2

plt.plot(x, y1)
plt.plot(x, y2)

# %%
x = np.arange(0, np.pi*2, 0.1)
sin = np.sin(x)
cos = np.cos(x)

plt.style.use("ggplot")

plt.plot(x, sin, "g--", label="sin(x)")
plt.plot(x, cos, color=(1, 0.7, 0), marker=".", linestyle="", label="cos(x)")

plt.title("Trigonometric functions")
plt.xlabel("x (radians)")
plt.ylabel("y")
plt.legend()
plt.axis("scaled")
plt.yticks([-1, 0, 1])
plt.xticks(np.linspace(0, 2*np.pi, 5))
# Out:
# ([<matplotlib.axis.XTick at 0x7f617ca53358>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
# Glockenkurve

x = np.linspace(-4, 4, 50)

y = 1 / np.sqrt(2 * np.pi) * np.exp(-0.5 * x**2)

# %%
plt.bar(x, y)
plt.plot(x, y, "g-")

# %%
plt.boxplot(iris_np[:, :4], labels=["a", "b", "c", "d"])
pass

# %%
plt.hist(iris_np[:, 2], bins=[1, 2, 4, 5, 6], density=True)
# Out:
# (array([0.35460993, 0.03900709, 0.30496454, 0.26241135]),
#  array([1, 2, 4, 5, 6]),
#  <a list of 4 Patch objects>)

# %%
plt.plot(iris_np[:,2], iris_np[:, 3], ".")
plt.axis("equal")
# Out:
# (0.705078125, 7.193359375, -0.02002563476562501, 2.620001220703125)

# %%
plt.scatter(iris_np[:,2], iris_np[:, 3], iris_np[:,0], iris_np[:, 1])

# %%
fig = plt.figure(
    figsize=(16, 12),
    facecolor="#eeeeee"
)
plt.pie([3, 10, 17, 9], explode=[0, 0, 0, 0.1])
fig.savefig("myplot.svg")

# %% [markdown]
# # axes & subplots

# %%
plt.figure(
    figsize=(16, 12),
    facecolor="#eeeeee"
)
fig, ax = plt.subplots(2, 2, figsize=(12, 12))

ax0 = ax[0, 0]
ax1 = ax[0, 1]
ax2 = ax[1, 0]
ax3 = ax[1, 1]

ax0.pie([3, 10, 17, 9], explode=[0, 0, 0, 0.1])
ax1.plot(iris_np[:,2], iris_np[:, 3], ".")
ax2.plot(iris_np[:,0], iris_np[:, 3], ".")
ax3.plot(iris_np[:,0], iris_np[:, 1], ".")
None

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/matplotlib/projections/__init__.py in get_projection_class(projection)
#      57     try:
# ---> 58         return projection_registry.get_projection_class(projection)
#      59     except KeyError:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/projections/__init__.py in get_projection_class(self, name)
#      24         """
# ---> 25         return self._all_projection_types[name]
#      26
#
# KeyError: '3d'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-2d638f2bf433> in <module>
#       1 fig = plt.figure()
# ----> 2 ax = plt.axes(projection='3d')
#
# ~/.local/lib/python3.7/site-packages/matplotlib/pyplot.py in axes(arg, **kwargs)
#     875
# ...
