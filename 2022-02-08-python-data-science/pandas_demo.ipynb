# %%
import pandas as pd

# %%
area = pd.Series({'CN': 9.6, 'RU': 17, 'US': 9.8})
population = pd.Series({'CN': 1386, 'RU': 144, 'US': 327})

# %%
area
# Out:
# CN     9.6
# RU    17.0
# US     9.8
# dtype: float64

# %%
population
# Out:
# CN    1386
# RU     144
# US     327
# dtype: int64

# %%
area[0]
# Out:
# 9.6

# %%
area["CN"]
# Out:
# 9.6

# %%
area.dtype
# Out:
# dtype('float64')

# %%
countries = pd.DataFrame(
    {"area": area, "population": population}
)

# %%
countries
# Out:
#     area  population
# CN   9.6        1386
# RU  17.0         144
# US   9.8         327

# %% [markdown]
# # Importing data

# %%
euribor = pd.read_csv(
    "https://datahub.io/core/euribor/r/euribor-12m-monthly.csv",
    sep="\t"
)

# %%
euribor = pd.read_csv(
    "https://datahub.io/core/euribor/r/euribor-12m-monthly.csv",
    parse_dates=["date"],
    index_col="date",
    usecols=["date", "rate"]
)

# %%
euribor.shape
# Out:
# (220, 1)

# %%
titanic = pd.read_csv(
    "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv",
    index_col="PassengerId",
)

# %%
sp500 = pd.read_csv(
    "https://datahub.io/core/s-and-p-500/r/data.csv",
    index_col="Date",
    parse_dates=["Date"],
)

# %%
exchange_rates = pd.read_csv(
    "https://datahub.io/core/us-euro-foreign-exchange-rate/r/monthly.csv",
    parse_dates=["Date"],
)

# %%
iris = pd.read_csv(
    "http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",
    header=None,
    names=["sepal_length", "sepal_width", "petal_length",
           "petal_width", "species"],
)

# %% [markdown]
# # selecting data

# %%
sp500.loc["1872-01-01"]
# Out:
# SP500                    4.86
# Dividend                 0.26
# Earnings                 0.40
# Consumer Price Index    12.65
# Long Interest Rate       5.36
# Real Price              95.95
# Real Dividend            5.20
# Real Earnings            7.95
# PE10                      NaN
# Name: 1872-01-01 00:00:00, dtype: float64

# %%
sp500.loc["1872-01-01" : "1872-12-31"]
# Out:
#             SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1872-01-01   4.86      0.26      0.40                 12.65
# 1872-02-01   4.88      0.27      0.41                 12.65
# 1872-03-01   5.04      0.27      0.41                 12.84
# 1872-04-01   5.18      0.27      0.41                 13.13
# 1872-05-01   5.18      0.28      0.41                 13.13
# 1872-06-01   5.13      0.28      0.41                 13.03
# 1872-07-01   5.10      0.28      0.42                 12.84
# 1872-08-01   5.04      0.29      0.42                 12.94
# 1872-09-01   4.95      0.29      0.42                 13.03
# 1872-10-01   4.97      0.29      0.42                 12.75
# 1872-11-01   4.95      0.30      0.43                 13.13
# 1872-12-01   5.07      0.30      0.43                 12.94
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  PE10
# Date
# 1872-01-01                5.36       95.95           5.20           7.95   NaN
# ...

# %%
sp500.iloc[0:10]
# Out:
#             SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1871-01-01   4.44      0.26       0.4                 12.46
# 1871-02-01   4.50      0.26       0.4                 12.84
# 1871-03-01   4.61      0.26       0.4                 13.03
# 1871-04-01   4.74      0.26       0.4                 12.56
# 1871-05-01   4.86      0.26       0.4                 12.27
# 1871-06-01   4.82      0.26       0.4                 12.08
# 1871-07-01   4.73      0.26       0.4                 12.08
# 1871-08-01   4.79      0.26       0.4                 11.89
# 1871-09-01   4.84      0.26       0.4                 12.18
# 1871-10-01   4.59      0.26       0.4                 12.37
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  PE10
# Date
# 1871-01-01                5.32       89.00           5.21           8.02   NaN
# 1871-02-01                5.32       87.53           5.06           7.78   NaN
# ...

# %%
titanic[titanic["Pclass"] == 1]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 12                  1       1
# 24                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 24                                Sloper, Mr. William Thompson    male  28.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic[titanic["Age"] > 60]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 34                  0       2                      Wheadon, Mr. Edward H
# 55                  0       1             Ostby, Mr. Engelhart Cornelius
# 97                  0       1                  Goldschmidt, Mr. George B
# 117                 0       3                       Connors, Mr. Patrick
# 171                 0       1                  Van der hoef, Mr. Wyckoff
# 253                 0       1                  Stead, Mr. William Thomas
# 276                 1       1          Andrews, Miss. Kornelia Theodosia
# 281                 0       3                           Duane, Mr. Frank
# 327                 0       3                  Nysveen, Mr. Johan Hansen
# 439                 0       1                          Fortune, Mr. Mark
# 457                 0       1                  Millet, Mr. Francis Davis
# 484                 1       3                     Turkula, Mrs. (Hedwig)
# ...

# %%
titanic.sample(frac=0.1)
# Out:
#              Survived  Pclass                                    Name     Sex  \
# PassengerId
# 29                  1       3           O'Dwyer, Miss. Ellen "Nellie"  female
# 543                 0       3       Andersson, Miss. Sigrid Elisabeth  female
# 677                 0       3           Sawyer, Mr. Frederick Charles    male
# 883                 0       3            Dahlberg, Miss. Gerda Ulrika  female
# 293                 0       2                  Levy, Mr. Rene Jacques    male
# ...               ...     ...                                     ...     ...
# 834                 0       3                  Augustsson, Mr. Albert    male
# 285                 0       1              Smith, Mr. Richard William    male
# 332                 0       1                     Partner, Mr. Austen    male
# 315                 0       2                      Hart, Mr. Benjamin    male
# 639                 0       3  Panula, Mrs. Juha (Maria Emilia Ojala)  female
#
# ...

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.sample(150)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 96            5.7          2.9           4.2          1.3  Iris-versicolor
# 130           7.4          2.8           6.1          1.9   Iris-virginica
# 106           4.9          2.5           4.5          1.7   Iris-virginica
# 127           6.1          3.0           4.9          1.8   Iris-virginica
# ..            ...          ...           ...          ...              ...
# 76            6.8          2.8           4.8          1.4  Iris-versicolor
# 144           6.7          3.3           5.7          2.5   Iris-virginica
# 69            5.6          2.5           3.9          1.1  Iris-versicolor
# 28            5.2          3.4           1.4          0.2      Iris-setosa
# 137           6.4          3.1           5.5          1.8   Iris-virginica
#
# [150 rows x 5 columns]

# %%
titanic["Pclass"] >= 2
# Out:
# PassengerId
# 1       True
# 2      False
# 3       True
# 4      False
# 5       True
#        ...
# 887     True
# 888    False
# 889     True
# 890    False
# 891     True
# Name: Pclass, Length: 891, dtype: bool

# %%
titanic["Sex"] == "male"
# Out:
# PassengerId
# 1       True
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 887     True
# 888    False
# 889    False
# 890     True
# 891     True
# Name: Sex, Length: 891, dtype: bool

# %%
titanic[(titanic["Pclass"] >= 2) & (titanic["Sex"] == "male")]
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 6                   0       3                Moran, Mr. James  male   NaN
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
# 13                  0       3  Saundercock, Mr. William Henry  male  20.0
# ...               ...     ...                             ...   ...   ...
# 882                 0       3              Markun, Mr. Johann  male  33.0
# 884                 0       2   Banfield, Mr. Frederick James  male  28.0
# 885                 0       3          Sutehall, Mr. Henry Jr  male  25.0
# 887                 0       2           Montvila, Rev. Juozas  male  27.0
# 891                 0       3             Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
titanic.query("Pclass >= 2 and Sex == 'male'")
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 6                   0       3                Moran, Mr. James  male   NaN
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
# 13                  0       3  Saundercock, Mr. William Henry  male  20.0
# ...               ...     ...                             ...   ...   ...
# 882                 0       3              Markun, Mr. Johann  male  33.0
# 884                 0       2   Banfield, Mr. Frederick James  male  28.0
# 885                 0       3          Sutehall, Mr. Henry Jr  male  25.0
# 887                 0       2           Montvila, Rev. Juozas  male  27.0
# 891                 0       3             Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
titanic[titanic["Embarked"].isin(["S", "Q"])]
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
# ...               ...     ...                                           ...
# 886                 0       3          Rice, Mrs. William (Margaret Norton)
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic["Survived"].astype("bool")
# Out:
# PassengerId
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 887    False
# 888     True
# 889    False
# 890     True
# 891    False
# Name: Survived, Length: 891, dtype: bool

# %%
iris["sepal_ratio"] = iris["sepal_length"] / iris["sepal_width"]

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      sepal_ratio
# 0       1.457143
# 1       1.633333
# 2       1.468750
# ...

# %%
sp500
# Out:
#               SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1871-01-01     4.44      0.26      0.40                 12.46
# 1871-02-01     4.50      0.26      0.40                 12.84
# 1871-03-01     4.61      0.26      0.40                 13.03
# 1871-04-01     4.74      0.26      0.40                 12.56
# 1871-05-01     4.86      0.26      0.40                 12.27
# ...             ...       ...       ...                   ...
# 2017-12-01  2664.34     48.93    109.88                246.52
# 2018-01-01  2789.80     49.29       NaN                247.87
# 2018-02-01  2705.16     49.64       NaN                248.99
# 2018-03-01  2702.77     50.00       NaN                249.55
# 2018-04-01  2642.19       NaN       NaN                249.84
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# Date
# 1871-01-01                5.32       89.00           5.21           8.02
# ...

# %%
sp500["Gewinn"] = sp500["SP500"].diff()

# %%
sp500
# Out:
#               SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1871-01-01     4.44      0.26      0.40                 12.46
# 1871-02-01     4.50      0.26      0.40                 12.84
# 1871-03-01     4.61      0.26      0.40                 13.03
# 1871-04-01     4.74      0.26      0.40                 12.56
# 1871-05-01     4.86      0.26      0.40                 12.27
# ...             ...       ...       ...                   ...
# 2017-12-01  2664.34     48.93    109.88                246.52
# 2018-01-01  2789.80     49.29       NaN                247.87
# 2018-02-01  2705.16     49.64       NaN                248.99
# 2018-03-01  2702.77     50.00       NaN                249.55
# 2018-04-01  2642.19       NaN       NaN                249.84
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# Date
# 1871-01-01                5.32       89.00           5.21           8.02
# ...

# %%
sp500["Gewinn Relativ"] = sp500["Gewinn"] / sp500["SP500"]

# %%
sp500
# Out:
#               SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1871-01-01     4.44      0.26      0.40                 12.46
# 1871-02-01     4.50      0.26      0.40                 12.84
# 1871-03-01     4.61      0.26      0.40                 13.03
# 1871-04-01     4.74      0.26      0.40                 12.56
# 1871-05-01     4.86      0.26      0.40                 12.27
# ...             ...       ...       ...                   ...
# 2017-12-01  2664.34     48.93    109.88                246.52
# 2018-01-01  2789.80     49.29       NaN                247.87
# 2018-02-01  2705.16     49.64       NaN                248.99
# 2018-03-01  2702.77     50.00       NaN                249.55
# 2018-04-01  2642.19       NaN       NaN                249.84
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# Date
# 1871-01-01                5.32       89.00           5.21           8.02
# ...

# %%
titanic["Age"].count()
# Out:
# 714

# %%
titanic.loc[titanic["Age"].isna()]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 6                   0       3                          Moran, Mr. James
# 18                  1       2              Williams, Mr. Charles Eugene
# 20                  1       3                   Masselmani, Mrs. Fatima
# 27                  0       3                   Emir, Mr. Farred Chehab
# 29                  1       3             O'Dwyer, Miss. Ellen "Nellie"
# ...               ...     ...                                       ...
# 860                 0       3                          Razi, Mr. Raihed
# 864                 0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869                 0       3               van Melkebeke, Mr. Philemon
# 879                 0       3                        Laleff, Mr. Kristo
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#                 Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %%
titanic.dropna(subset=["Age"])
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data = pd.Series(
    [1, 2, 4, np.nan, 16, 32, np.nan, np.nan, 256]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13572/2890986761.py in <module>
#       1 data = pd.Series(
# ----> 2     [1, 2, 4, np.nan, 16, 32, np.nan, np.nan, 256]
#       3 )
#
# NameError: name 'np' is not defined

# %%
data_interpolated = data.interpolate("quadratic")
data_interpolated.plot()

# %%
import numpy as np
import pandas as pd

x = np.array([0, 1, 2, 3])

data = pd.DataFrame({
    "y1": x*2,
    "y2": x**2
})

data.plot()

# %%
sp500.plot.line()

# %%
titanic.plot()

# %%
iris.plot.scatter(
    x="sepal_length",
    y="sepal_width",
    s="petal_length",
    c="petal_width"
)

# %%
iris["sepal_length"].plot.hist()

# %%
iris.plot.box()

# %%
surface = pd.Series([0.29, 0.71], index=["land", "water"])

surface.plot.pie(ylabel="Surface of the earth")

# %%
pop = countries["population"].sort_values(ascending=False)
pop.plot.bar()
pop.cumsum().plot.line(color="C1")

# %%
from pandas.plotting import scatter_matrix
 
scatter_matrix(iris, figsize=(16, 12));

# %%
sp500
# Out:
#               SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1871-01-01     4.44      0.26      0.40                 12.46
# 1871-02-01     4.50      0.26      0.40                 12.84
# 1871-03-01     4.61      0.26      0.40                 13.03
# 1871-04-01     4.74      0.26      0.40                 12.56
# 1871-05-01     4.86      0.26      0.40                 12.27
# ...             ...       ...       ...                   ...
# 2017-12-01  2664.34     48.93    109.88                246.52
# 2018-01-01  2789.80     49.29       NaN                247.87
# 2018-02-01  2705.16     49.64       NaN                248.99
# 2018-03-01  2702.77     50.00       NaN                249.55
# 2018-04-01  2642.19       NaN       NaN                249.84
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# Date
# 1871-01-01                5.32       89.00           5.21           8.02
# ...

# %%
exchange_rates
# Out:
#             Date    Country  Exchange rate
# 0     1971-01-01  Australia       0.894374
# 1     1971-02-01  Australia       0.889838
# 2     1971-03-01  Australia       0.889442
# 3     1971-04-01  Australia       0.889838
# 4     1971-05-01  Australia       0.889442
# ...          ...        ...            ...
# 15599 2020-03-01  Venezuela   73313.712700
# 15600 2020-04-01  Venezuela  121810.004100
# 15601 2020-05-01  Venezuela  181598.485000
# 15602 2020-06-01  Venezuela  200471.150000
# 15603 2020-07-01  Venezuela  225169.909100
#
# [15604 rows x 3 columns]

# %%
exchange_rates = pd.read_csv(
    "https://datahub.io/core/us-euro-foreign-exchange-rate/r/monthly.csv",
    index_col=["Country", "Date"],
    parse_dates=["Date"])

# %%
exchange_rates
# Out:
#                       Exchange rate
# Country   Date
# Australia 1971-01-01       0.894374
#           1971-02-01       0.889838
#           1971-03-01       0.889442
#           1971-04-01       0.889838
#           1971-05-01       0.889442
# ...                             ...
# Venezuela 2020-03-01   73313.712700
#           2020-04-01  121810.004100
#           2020-05-01  181598.485000
#           2020-06-01  200471.150000
#           2020-07-01  225169.909100
#
# [15604 rows x 1 columns]

# %%
exchange_rates_series = exchange_rates["Exchange rate"]

# %%
exchange_rates_series
# Out:
# Country    Date
# Australia  1971-01-01         0.894374
#            1971-02-01         0.889838
#            1971-03-01         0.889442
#            1971-04-01         0.889838
#            1971-05-01         0.889442
#                              ...
# Venezuela  2020-03-01     73313.712700
#            2020-04-01    121810.004100
#            2020-05-01    181598.485000
#            2020-06-01    200471.150000
#            2020-07-01    225169.909100
# Name: Exchange rate, Length: 15604, dtype: float64

# %%
exchange_rates_series["Germany", "1980-01-01"]
# Out:
# 1.7246

# %%
# JOINS

# "outer join"
interest_rates = pd.DataFrame({
    "usd": sp500["Long Interest Rate"],
    "eur": euribor["rate"]
})
interest_rates
# Out:
#              usd  eur
# 1871-01-01  5.32  NaN
# 1871-02-01  5.32  NaN
# 1871-03-01  5.33  NaN
# 1871-04-01  5.33  NaN
# 1871-05-01  5.33  NaN
# ...          ...  ...
# 2017-12-01  2.40  NaN
# 2018-01-01  2.58  NaN
# 2018-02-01  2.86  NaN
# 2018-03-01  2.84  NaN
# 2018-04-01  2.80  NaN
#
# [1855 rows x 2 columns]

# %%
# inner join

interest_rates = pd.DataFrame({
    "usd": sp500["Long Interest Rate"],
    "eur": euribor["rate"]
}).dropna()
interest_rates
# Out:
#              usd    eur
# 1999-01-01  4.72  3.213
# 1999-02-01  5.00  2.998
# 1999-03-01  5.23  3.079
# 1999-04-01  5.18  2.939
# 1999-06-01  5.90  2.735
# ...          ...    ...
# 2016-09-01  1.63 -0.051
# 2016-11-01  2.14 -0.069
# 2016-12-01  2.49 -0.079
# 2017-02-01  2.42 -0.103
# 2017-03-01  2.48 -0.114
#
# [133 rows x 2 columns]

# %%
pd.merge(sp500, euribor, left_index=True, right_index=True, how="right")
# Out:
#               SP500  Dividend  Earnings  Consumer Price Index  \
# date
# 1999-01-01  1248.77     16.28     37.93                164.30
# 1999-02-01  1246.58     16.37     38.16                164.50
# 1999-03-01  1281.66     16.45     38.38                165.00
# 1999-04-01  1334.76     16.45     39.26                166.20
# 1999-05-03      NaN       NaN       NaN                   NaN
# ...             ...       ...       ...                   ...
# 2016-12-01  2246.63     45.70     94.55                241.43
# 2017-01-02      NaN       NaN       NaN                   NaN
# 2017-02-01  2329.91     46.15     98.38                243.60
# 2017-03-01  2366.82     46.38    100.29                243.80
# 2017-04-03      NaN       NaN       NaN                   NaN
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# date
# 1999-01-01                4.72     1898.89          24.76          57.68
# ...

# %%
titanic.groupby("Pclass")["Age"].median()
# Out:
# Pclass
# 1    37.0
# 2    29.0
# 3    24.0
# Name: Age, dtype: float64

# %%
pd.crosstab(titanic["Pclass"], titanic["Sex"])
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
import numpy as np

pd.crosstab(
    index=titanic["Pclass"],
    columns=titanic["Sex"],
    values=titanic["Age"],
    aggfunc=np.mean)
# Out:
# Sex        female       male
# Pclass
# 1       34.611765  41.281386
# 2       28.722973  30.740707
# 3       21.750000  26.507589

# %%
ratings = pd.read_csv(
    "https://files.grouplens.org/datasets/movielens/ml-100k/u.data",
    sep="\t",
    header=None,
    usecols=[0, 1, 2],
    names=["user_id", "movie_id", "rating"],
)
movie_titles = pd.read_csv(
    "https://files.grouplens.org/datasets/movielens/ml-100k/u.item",
    sep="|",
    header=None,
    encoding="latin1",
    usecols=[0, 1],
    names=["movie_id", "title"],
)

# %%
movie_names = movie_titles.groupby("movie_id")["title"].first()
movie_mean_ratings = ratings.groupby("movie_id")["rating"].mean()
movie_num_ratings = ratings.groupby("movie_id")["rating"].count()

movie_ratings = pd.DataFrame({
  "name": movie_names,
  "mean_rating": movie_mean_ratings,
  "num_ratings": movie_num_ratings
})

movie_ratings.query(
    "num_ratings >= 10 and 4.2 < mean_rating"
).sort_values(by="mean_rating", ascending=False)
# Out:
#                                                        name  mean_rating  \
# movie_id
# 408                                   Close Shave, A (1995)     4.491071
# 318                                 Schindler's List (1993)     4.466443
# 169                              Wrong Trousers, The (1993)     4.466102
# 483                                       Casablanca (1942)     4.456790
# 114       Wallace & Gromit: The Best of Aardman Animatio...     4.447761
# 64                         Shawshank Redemption, The (1994)     4.445230
# 603                                      Rear Window (1954)     4.387560
# 12                               Usual Suspects, The (1995)     4.385768
# 50                                         Star Wars (1977)     4.358491
# 178                                     12 Angry Men (1957)     4.344000
# 513                                   Third Man, The (1949)     4.333333
# 134                                     Citizen Kane (1941)     4.292929
# ...

# %%
sp500_new = sp500.drop([
    "1871-01-01",
    "1871-02-01",
])

# %%
sp500_new
# Out:
#               SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1871-03-01     4.61      0.26      0.40                 13.03
# 1871-04-01     4.74      0.26      0.40                 12.56
# 1871-05-01     4.86      0.26      0.40                 12.27
# 1871-06-01     4.82      0.26      0.40                 12.08
# 1871-07-01     4.73      0.26      0.40                 12.08
# ...             ...       ...       ...                   ...
# 2017-12-01  2664.34     48.93    109.88                246.52
# 2018-01-01  2789.80     49.29       NaN                247.87
# 2018-02-01  2705.16     49.64       NaN                248.99
# 2018-03-01  2702.77     50.00       NaN                249.55
# 2018-04-01  2642.19       NaN       NaN                249.84
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# Date
# 1871-03-01                5.33       88.36           4.98           7.67
# ...

# %%
sp500["SP500"].to_period().resample("Y").mean()
# Out:
# Date
# 1871       4.691667
# 1872       5.029167
# 1873       4.801667
# 1874       4.570000
# 1875       4.447500
#            ...
# 2014    1930.667500
# 2015    2061.199167
# 2016    2091.844167
# 2017    2448.217500
# 2018    2709.980000
# Freq: A-DEC, Name: SP500, Length: 148, dtype: float64

# %%
sp500["SP500"].to_period().resample("D").interpolate()
# Out:
# Date
# 1871-01-01       4.440000
# 1871-01-02       4.441935
# 1871-01-03       4.443871
# 1871-01-04       4.445806
# 1871-01-05       4.447742
#                  ...
# 2018-04-26    2642.190000
# 2018-04-27    2642.190000
# 2018-04-28    2642.190000
# 2018-04-29    2642.190000
# 2018-04-30    2642.190000
# Freq: D, Name: SP500, Length: 53811, dtype: float64

# %%
sp500.index.equals(
    pd.date_range(
        sp500.index[0], sp500.index[-1], freq="MS"
    )
)
# Out:
# True

# %%
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(8),
    keras.layers.Activation("relu"),
    keras.layers.Dense(3),
    keras.layers.Activation("softmax")
])
model.compile(
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
iris["sepal_length_square"] = iris["sepal_length"]**2

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      sepal_ratio  sepal_length_square
# 0       1.457143                26.01
# ...

# %%
from sklearn.datasets import load_diabetes

# load dataset as a pandas dataframe
dataset = load_diabetes(as_frame=True)

print(dataset.data)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
import statsmodels.api as sm

# add constant column for base value of y (intercept)
x = sm.add_constant(dataset.data)

y = dataset.target

# %%
model = sm.OLS(y, x)

res = model.fit()

res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     46.27
# Date:                Tue, 08 Feb 2022   Prob (F-statistic):           3.83e-62
# Time:                        13:56:06   Log-Likelihood:                -2386.0
# No. Observations:                 442   AIC:                             4794.
# Df Residuals:                     431   BIC:                             4839.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        152.1335      2.576     59.061      0.000     147.071     157.196
# ...

# %%
import pickle

with open("data.pickle", mode="wb") as picklefile:
    pickle.dump(iris, picklefile)

# %%
with open("data.pickle", mode="rb") as picklefile:
