# %%
import titanic
# Out:
# 891 passengers (314 women)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7948/902514334.py in <module>
# ----> 1 import titanic
#
# ~\docs\repos\courses-code\2021-09-20-data-analysis-in-python-pandas-numpy\titanic.py in <module>
#      42 titanic.visualize_ages()
#      43
# ---> 44 titanic.save_data()
#
# ~\docs\repos\courses-code\2021-09-20-data-analysis-in-python-pandas-numpy\titanic.py in save_data(self)
#      28     def save_data(self):
#      29         self._data.to_sql("titanic", con=self._db_engine)
# ---> 30         self._data.to_sql("titanic", con=self._db_engine)
#      31
#      32
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# ...
