# %%
import pandas as pd

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
# Aufgaben

# - Altersverteilung
# - Altersverteilung in der 1. Klasse

# - Zusammenhang: Alter - Klasse
# - Zusammenhang: Klasse - Ticketpreis

# %%
import matplotlib.pyplot as plt
titanic["Age"]

plt.hist(titanic["Age"], align="left");

# %%
titanic["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic_cleaned = titanic.dropna(subset=("Age",))

# %%
titanic_cleaned["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# Altersverteilung in der 1. Klasse

plt.hist(titanic["Age"], align="left");
plt.hist(titanic[titanic["Pclass"]==1]["Age"], align="left");

# %%
# Zusammenhang Alter - Klasse

plt.scatter(titanic["Pclass"], titanic["Age"], alpha=0.05);

# %%
titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
from scipy.stats import pearsonr

corr, _ = pearsonr(titanic_cleaned['Pclass'], titanic_cleaned['Age'])

# %%
corr
# Out:
# -0.36922601531551735

# %%
import seaborn as sns

sns.heatmap(titanic.corr())
# Out:
# <AxesSubplot:>

# %%
titanic[
    (titanic["Age"] >= 18) & (titanic["Sex"] == "male")
].sort_values(by="Age")
# Out:
#      PassengerId  Survived  Pclass  \
# 834          835         0       3
# 175          176         0       3
# 675          676         0       3
# 385          386         0       2
# 505          506         0       1
# ..           ...       ...     ...
# 116          117         0       3
# 96            97         0       1
# 493          494         0       1
# 851          852         0       3
# 630          631         1       1
#
#                                            Name   Sex   Age  SibSp  Parch  \
# 834                      Allum, Mr. Owen George  male  18.0      0      0
# 175                      Klasen, Mr. Klas Albin  male  18.0      1      1
# 675              Edvardsson, Mr. Gustaf Hjalmar  male  18.0      0      0
# 385                   Davies, Mr. Charles Henry  male  18.0      0      0
# 505  Penasco y Castellana, Mr. Victor de Satode  male  18.0      1      0
# ..                                          ...   ...   ...    ...    ...
# ...

# %%
titanic.loc[titanic["Age"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
by_age = titanic.groupby("Pclass")["Age"]

# %%
by_age.median()
# Out:
# Pclass
# 1    37.0
# 2    29.0
# 3    24.0
# Name: Age, dtype: float64

# %%
pd.crosstab(titanic["Pclass"], titanic["Sex"])
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
import numpy as np
pd.crosstab(
    index=titanic["Pclass"],
    columns=titanic["Sex"],
    values=titanic["Age"],
    aggfunc=np.mean)
# Out:
# Sex        female       male
# Pclass
# 1       34.611765  41.281386
# 2       28.722973  30.740707
# 3       21.750000  26.507589
