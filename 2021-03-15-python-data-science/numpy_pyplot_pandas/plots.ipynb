# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.bar(
    [0, 1, 2],
    [9.6, 17, 9.8],
    tick_label=["China", "Russia", "USA"]
)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh([0, 1, 2], [9.6, 17, 9.8])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie([3, 10, 17, 9], labels=["a", "b", "c", "d"])
# Out:
# ([<matplotlib.patches.Wedge at 0x24d231a45b0>,
#   <matplotlib.patches.Wedge at 0x24d231a4a90>,
#   <matplotlib.patches.Wedge at 0x24d231a4eb0>,
#   <matplotlib.patches.Wedge at 0x24d231b0370>],
#  [Text(1.068035996798755, 0.26324724033138536, 'a'),
#   Text(0.30603914309104063, 1.0565699422641655, 'b'),
#   Text(-1.0433900439116068, -0.348334919676646, 'c'),
#   Text(0.8233619228034269, -0.7294348113967717, 'd')])

# %%
plt.pie([3, 10, 17, 9], startangle=90, counterclock=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x24d2323c790>,
#   <matplotlib.patches.Wedge at 0x24d2323cc70>,
#   <matplotlib.patches.Wedge at 0x24d23249130>,
#   <matplotlib.patches.Wedge at 0x24d232495b0>],
#  [Text(0.26324724033138536, 1.068035996798755, ''),
#   Text(1.0565699422641655, 0.3060391430910406, ''),
#   Text(-0.34833491967664604, -1.0433900439116068, ''),
#   Text(-0.7294348113967719, 0.8233619228034267, '')])
