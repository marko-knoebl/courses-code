# %%
import pandas as pd

euribor = pd.read_csv(
    "https://datahub.io/core/euribor/r/euribor-12m-monthly.csv",
    parse_dates=["date"],
    index_col="date",
    usecols=["date", "rate"]
)
sp500 = pd.read_csv(
    "https://datahub.io/core/s-and-p-500/r/data.csv",
    index_col="Date",
    parse_dates=["Date"],
)
exchange_rates = pd.read_csv(
    "https://datahub.io/core/us-euro-foreign-exchange-rate/r/monthly.csv",
    parse_dates=["Date"]
)
iris = pd.read_csv(
    "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
)
titanic = pd.read_csv(
    "https://public.opendatasoft.com/explore/dataset/titanic-passengers/download",
    sep=";",
)

# %%
# Aufgabe: Visualisierung verschiedener Daten aus pandas
# Siehe: "Plotting: Beispiele und Übungen" (Abschnitt 10)

# %%
euribor.plot.line()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
sp500["SP500"].plot.line()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
euribor.iloc[-100:-50].plot.bar()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
iris_setosa = iris.loc[iris["species"]=="setosa"]
iris_setosa_medians = iris_setosa.median()
iris_setosa_sepal_width_median = iris_setosa_medians["sepal_width"]
iris_setosa_sepal_length_median = iris_setosa_medians["sepal_length"]
iris_setosa_medians = pd.Series([
    iris_setosa_sepal_width_median,
    iris_setosa_sepal_length_median
], index=["sepal_width", "sepal_length"])

iris_virginica = iris.loc[iris["species"]=="virginica"]
iris_virginica_medians = iris_virginica.median()[["sepal_width", "sepal_length"]]
print(iris_virginica_medians)
print(iris_setoas_medians)

medians = pd.DataFrame({
    "setosa": iris_setosa_medians,
    "virginica": iris_virginica_medians
})
medians.T.plot.bar()
# Out:
# sepal_width     3.0
# sepal_length    6.5
# dtype: float64
# sepal_width     3.4
# sepal_length    5.0
# dtype: float64
# <AxesSubplot:>

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(iris);
