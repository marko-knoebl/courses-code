# %%
import pandas as pd

# %%
area = pd.Series({'CN': 9.6, 'RU': 17, 'US': 9.8})
population = pd.Series({'CN': 1386, 'RU': 144, 'US': 327})

# %%
area.dtype
# Out:
# dtype('float64')

# %%
countries = pd.DataFrame(
    {"area": area, "population": population}
)

# %%
countries
# Out:
#     area  population
# CN   9.6        1386
# RU  17.0         144
# US   9.8         327

# %% [markdown]
# # Importing data

# %%
euribor = pd.read_csv(
    "https://raw.githubusercontent.com/datasets/euribor/master/data/euribor-12m-monthly.csv"
)

# %%
euribor
# Out:
#            date   rate maturity_level granularity
# 0    2014-01-02  0.555            12m     monthly
# 1    2014-02-03  0.549            12m     monthly
# 2    2014-03-03  0.554            12m     monthly
# 3    2014-04-01  0.591            12m     monthly
# 4    2014-05-02  0.612            12m     monthly
# ..          ...    ...            ...         ...
# 127  2024-08-01  3.349            12m     monthly
# 128  2024-09-02  3.072            12m     monthly
# 129  2024-10-01  2.749            12m     monthly
# 130  2024-11-01  2.629            12m     monthly
# 131  2024-12-02  2.431            12m     monthly
#
# [132 rows x 4 columns]

# %%
euribor = pd.read_csv(
    "https://raw.githubusercontent.com/datasets/euribor/master/data/euribor-12m-monthly.csv",
    parse_dates=["date"],
    index_col="date",
    usecols=["date", "rate"]
)
sp500 = pd.read_csv(
    "https://raw.githubusercontent.com/datasets/s-and-p-500/main/data/data.csv",
    index_col="Date",
    parse_dates=["Date"],
)
iris = pd.read_csv(
    "http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",
    header=None,
    names=["sepal_length", "sepal_width", "petal_length",
           "petal_width", "species"],
)
titanic = pd.read_csv(
    "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv",
    index_col="PassengerId",
)

# %%
euribor
# Out:
#              rate
# date
# 2014-01-02  0.555
# 2014-02-03  0.549
# 2014-03-03  0.554
# 2014-04-01  0.591
# 2014-05-02  0.612
# ...           ...
# 2024-08-01  3.349
# 2024-09-02  3.072
# 2024-10-01  2.749
# 2024-11-01  2.629
# 2024-12-02  2.431
#
# [132 rows x 1 columns]

# %%
sp500 = pd.read_csv(
    "https://raw.githubusercontent.com/datasets/s-and-p-500/main/data/data.csv",
    index_col="Date",
    parse_dates=["Date"],
)

# %%
sp500.dtypes
# Out:
# SP500                   float64
# Dividend                float64
# Earnings                float64
# Consumer Price Index    float64
# Long Interest Rate      float64
# Real Price              float64
# Real Dividend           float64
# Real Earnings           float64
# PE10                    float64
# dtype: object

# %%
sp500
# Out:
#                   SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1871-01-01     4.440000      0.26      0.40                 12.46
# 1871-02-01     4.500000      0.26      0.40                 12.84
# 1871-03-01     4.610000      0.26      0.40                 13.03
# 1871-04-01     4.740000      0.26      0.40                 12.56
# 1871-05-01     4.860000      0.26      0.40                 12.27
# ...                 ...       ...       ...                   ...
# 2023-05-01  4146.173182     68.54    179.17                304.13
# 2023-06-01  4345.372857     68.71    181.17                305.11
# 2023-07-01  4508.075500      0.00      0.00                305.69
# 2023-08-01  4457.358696      0.00      0.00                305.98
# 2023-09-01  4515.770000      0.00      0.00                306.13
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# Date
# 1871-01-01                5.32      109.05           6.39           9.82
# ...

# %%
euribor.shape
# Out:
# (132, 1)

# %%
titanic.shape
# Out:
# (891, 11)

# %% [markdown]
# # Data Statistics

# %%
titanic.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic["SibSp"].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
titanic["SibSp"].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %% [markdown]
# # Querying Data

# %%
sp500.index
# Out:
# DatetimeIndex(['1871-01-01', '1871-02-01', '1871-03-01', '1871-04-01',
#                '1871-05-01', '1871-06-01', '1871-07-01', '1871-08-01',
#                '1871-09-01', '1871-01-01',
#                ...
#                '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
#                '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01',
#                '2023-08-01', '2023-09-01'],
#               dtype='datetime64[ns]', name='Date', length=1833, freq=None)

# %%
sp500.columns
# Out:
# Index(['SP500', 'Dividend', 'Earnings', 'Consumer Price Index',
#        'Long Interest Rate', 'Real Price', 'Real Dividend', 'Real Earnings',
#        'PE10'],
#       dtype='object')

# %%
titanic["Age"]
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889     NaN
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %%
sp500["Real Price"]
# Out:
# Date
# 1871-01-01     109.05
# 1871-02-01     107.25
# 1871-03-01     108.27
# 1871-04-01     115.54
# 1871-05-01     121.22
#                ...
# 2023-05-01    4173.45
# 2023-06-01    4359.88
# 2023-07-01    4514.51
# 2023-08-01    4459.48
# 2023-09-01    4515.77
# Name: Real Price, Length: 1833, dtype: float64

# %%
sp500.loc["1872-01-01"]
# Out:
#             SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1872-01-01   4.86      0.26    0.4025                 12.65
# 1872-01-01   4.97      0.29    0.4250                 12.75
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  PE10
# Date
# 1872-01-01                5.36      117.57           6.37           9.74   0.0
# 1872-01-01                5.52      119.33           7.04          10.20   0.0

# %%
sp500.loc["2009"]
# Out:
#               SP500  Dividend   Earnings  Consumer Price Index  \
# Date
# 2009-01-01   865.58     28.01  12.206667                211.14
# 2009-02-01   805.23     27.64   9.533333                212.19
# 2009-03-01   757.13     27.26   6.860000                212.71
# 2009-04-01   848.15     26.70   7.076667                213.24
# 2009-05-01   902.41     26.15   7.293333                213.86
# 2009-06-01   926.12     25.59   7.510000                215.69
# 2009-07-01   935.82     25.03   9.186667                215.35
# 2009-08-01  1009.73     24.46  10.863333                215.83
# 2009-09-01  1044.55     23.90  12.540000                215.97
# 2009-01-01  1067.66     23.40  25.350000                216.18
# 2009-11-01  1088.07     22.91  38.160000                216.33
# 2009-12-01  1110.38     22.41  50.970000                215.95
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# Date
# ...

# %%
sp500.iloc[0:10]
# Out:
#             SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1871-01-01   4.44      0.26       0.4                 12.46
# 1871-02-01   4.50      0.26       0.4                 12.84
# 1871-03-01   4.61      0.26       0.4                 13.03
# 1871-04-01   4.74      0.26       0.4                 12.56
# 1871-05-01   4.86      0.26       0.4                 12.27
# 1871-06-01   4.82      0.26       0.4                 12.08
# 1871-07-01   4.73      0.26       0.4                 12.08
# 1871-08-01   4.79      0.26       0.4                 11.89
# 1871-09-01   4.84      0.26       0.4                 12.18
# 1871-01-01   4.59      0.26       0.4                 12.37
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  PE10
# Date
# 1871-01-01                5.32      109.05           6.39           9.82   0.0
# 1871-02-01                5.32      107.25           6.20           9.53   0.0
# ...

# %%
titanic[titanic["Age"] >= 70]
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 97                  0       1             Goldschmidt, Mr. George B  male
# 117                 0       3                  Connors, Mr. Patrick  male
# 494                 0       1               Artagaveytia, Mr. Ramon  male
# 631                 1       1  Barkworth, Mr. Algernon Henry Wilson  male
# 673                 0       2           Mitchell, Mr. Henry Michael  male
# 746                 0       1          Crosby, Capt. Edward Gifford  male
# 852                 0       3                   Svensson, Mr. Johan  male
#
#               Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# 97           71.0      0      0    PC 17754  34.6542    A5        C
# 117          70.5      0      0      370369   7.7500   NaN        Q
# 494          71.0      0      0    PC 17609  49.5042   NaN        C
# 631          80.0      0      0       27042  30.0000   A23        S
# ...

# %%
titanic.sample(frac=0.01)
# Out:
#              Survived  Pclass                                 Name     Sex  \
# PassengerId
# 532                 0       3                    Toufik, Mr. Nakli    male
# 369                 1       3                  Jermyn, Miss. Annie  female
# 803                 1       1  Carter, Master. William Thornton II    male
# 271                 0       1                Cairns, Mr. Alexander    male
# 806                 0       3            Johansson, Mr. Karl Johan    male
# 589                 0       3                Gilinski, Mr. Eliezer    male
# 114                 0       3              Jussila, Miss. Katriina  female
# 95                  0       3                    Coxon, Mr. Daniel    male
# 194                 1       2           Navratil, Master. Michel M    male
#
#               Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# PassengerId
# 532           NaN      0      0    2641    7.2292      NaN        C
# ...

# %%
titanic["Age"].sort_values()
# Out:
# PassengerId
# 804    0.42
# 756    0.67
# 645    0.75
# 470    0.75
# 79     0.83
#        ...
# 860     NaN
# 864     NaN
# 869     NaN
# 879     NaN
# 889     NaN
# Name: Age, Length: 891, dtype: float64

# %%
titanic.sort_values(["Pclass", "Age"])
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 306                 1       1            Allison, Master. Hudson Trevor
# 298                 0       1              Allison, Miss. Helen Loraine
# 446                 1       1                 Dodge, Master. Washington
# 803                 1       1       Carter, Master. William Thornton II
# 436                 1       1                 Carter, Miss. Lucile Polk
# ...               ...     ...                                       ...
# 860                 0       3                          Razi, Mr. Raihed
# 864                 0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869                 0       3               van Melkebeke, Mr. Philemon
# 879                 0       3                        Laleff, Mr. Kristo
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#                 Sex    Age  SibSp  Parch      Ticket      Fare    Cabin  \
# PassengerId
# ...

# %%
titanic[(titanic["Pclass"] >= 2) & (titanic["Sex"] == "male")]
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 6                   0       3                Moran, Mr. James  male   NaN
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
# 13                  0       3  Saundercock, Mr. William Henry  male  20.0
# ...               ...     ...                             ...   ...   ...
# 882                 0       3              Markun, Mr. Johann  male  33.0
# 884                 0       2   Banfield, Mr. Frederick James  male  28.0
# 885                 0       3          Sutehall, Mr. Henry Jr  male  25.0
# 887                 0       2           Montvila, Rev. Juozas  male  27.0
# 891                 0       3             Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
titanic.query("Pclass >= 2 and Sex == 'male'")
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 6                   0       3                Moran, Mr. James  male   NaN
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
# 13                  0       3  Saundercock, Mr. William Henry  male  20.0
# ...               ...     ...                             ...   ...   ...
# 882                 0       3              Markun, Mr. Johann  male  33.0
# 884                 0       2   Banfield, Mr. Frederick James  male  28.0
# 885                 0       3          Sutehall, Mr. Henry Jr  male  25.0
# 887                 0       2           Montvila, Rev. Juozas  male  27.0
# 891                 0       3             Dooley, Mr. Patrick  male  32.0
#
# ...

# %% [markdown]
# # Plotting

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 1, 2, 3])

y1 = x*2
y2 = x**2

plt.plot(x, y1)
plt.plot(x, y2)

# %%
titanic["Age"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic["Age"].plot.box()
# Out:
# <Axes: >

# %%
sp500["SP500"].plot.line()
# Out:
# <Axes: xlabel='Date'>

# %%
sp500["SP500"].iloc[-12:].plot.bar()
# Out:
# <Axes: xlabel='Date'>

# %%
iris.plot.scatter(
    x="sepal_length",
    y="sepal_width"
)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
data = pd.Series({"a": 50, "b": 30, "c": 20})
data.plot.pie(ylabel="Data")
# Out:
# <Axes: ylabel='Data'>

# %%
titanic["Pclass"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
iris["sepal_ratio"] = iris["sepal_length"] / iris["sepal_width"]

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      sepal_ratio
# 0       1.457143
# 1       1.633333
# 2       1.468750
# ...

# %%
iris["sepal_ratio"].mean()
# Out:
# 1.955144430869462

# %%
iris["sepal_ratio"].std()
# Out:
# 0.39869729345326127

# %%
iris_setosa = iris.loc[
    iris["species"] == "Iris-setosa"
]

# %%
iris_setosa["sepal_ratio"].mean()
# Out:
# 1.474578362026333

# %%
iris_setosa["sepal_ratio"].std()
# Out:
# 0.1186927150032269

# %%
sp500["Diff"] = sp500["SP500"].diff()

# %%
sp500
# Out:
#                   SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1871-01-01     4.440000      0.26      0.40                 12.46
# 1871-02-01     4.500000      0.26      0.40                 12.84
# 1871-03-01     4.610000      0.26      0.40                 13.03
# 1871-04-01     4.740000      0.26      0.40                 12.56
# 1871-05-01     4.860000      0.26      0.40                 12.27
# ...                 ...       ...       ...                   ...
# 2023-05-01  4146.173182     68.54    179.17                304.13
# 2023-06-01  4345.372857     68.71    181.17                305.11
# 2023-07-01  4508.075500      0.00      0.00                305.69
# 2023-08-01  4457.358696      0.00      0.00                305.98
# 2023-09-01  4515.770000      0.00      0.00                306.13
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# Date
# 1871-01-01                5.32      109.05           6.39           9.82
# ...

# %%
sp500["Gain"] = sp500["Diff"] / sp500["SP500"]

# %%
sp500
# Out:
#                   SP500  Dividend  Earnings  Consumer Price Index  \
# Date
# 1871-01-01     4.440000      0.26      0.40                 12.46
# 1871-02-01     4.500000      0.26      0.40                 12.84
# 1871-03-01     4.610000      0.26      0.40                 13.03
# 1871-04-01     4.740000      0.26      0.40                 12.56
# 1871-05-01     4.860000      0.26      0.40                 12.27
# ...                 ...       ...       ...                   ...
# 2023-05-01  4146.173182     68.54    179.17                304.13
# 2023-06-01  4345.372857     68.71    181.17                305.11
# 2023-07-01  4508.075500      0.00      0.00                305.69
# 2023-08-01  4457.358696      0.00      0.00                305.98
# 2023-09-01  4515.770000      0.00      0.00                306.13
#
#             Long Interest Rate  Real Price  Real Dividend  Real Earnings  \
# Date
# 1871-01-01                5.32      109.05           6.39           9.82
# ...

# %%
titanic["Age"].isna()
# Out:
# PassengerId
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 887    False
# 888    False
# 889     True
# 890    False
# 891    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic["Age"]
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889     NaN
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic[titanic["Age"].isna()]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 6                   0       3                          Moran, Mr. James
# 18                  1       2              Williams, Mr. Charles Eugene
# 20                  1       3                   Masselmani, Mrs. Fatima
# 27                  0       3                   Emir, Mr. Farred Chehab
# 29                  1       3             O'Dwyer, Miss. Ellen "Nellie"
# ...               ...     ...                                       ...
# 860                 0       3                          Razi, Mr. Raihed
# 864                 0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869                 0       3               van Melkebeke, Mr. Philemon
# 879                 0       3                        Laleff, Mr. Kristo
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#                 Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %%
titanic_without_nas = titanic.dropna()

# %%
titanic_without_nas
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic_valid_ages = titanic.dropna(subset=["Age"])

# %%
titanic_valid_ages
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic["Age"].fillna(0)
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889     0.0
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic["Age"].fillna(method="ffill")
# Out:
# C:\Users\marko\AppData\Local\Temp\ipykernel_15116\808089072.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   titanic["Age"].fillna(method="ffill")
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889    19.0
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data = pd.Series(
    [1, 2, 4, np.nan, 16, 32, np.nan, np.nan, 256]
)

# %%
data.plot.bar()
# Out:
# <Axes: >

# %%
data.interpolate("quadratic").plot.bar()
# Out:
# <Axes: >

# %%
interest_rates = pd.DataFrame({
    "usd": sp500["Long Interest Rate"],
    "eur": euribor["rate"]
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 interest_rates = pd.DataFrame({
#       2     "usd": sp500["Long Interest Rate"],
#       3     "eur": euribor["rate"]
#       4 })
#
# File c:\Users\marko\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
#     769     from numpy.ma import mrecords
#
# ...

# %%
sp500_no_index = pd.read_csv(
    "https://datahub.io/core/s-and-p-500/r/data.csv",
    parse_dates=["Date"],
)
euribor_no_index = pd.read_csv(
    "https://datahub.io/core/euribor/r/euribor-12m-monthly.csv",
    parse_dates=["date"],
    usecols=["date", "rate"]
)

joined_data = pd.merge(sp500_no_index, euribor_no_index, left_on="Date",
         right_on="date", how="outer")

# %%
joined_data.plot.line()
# Out:
# c:\Users\marko\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\cbook.py:1699: UserWarning: Warning: converting a masked element to nan.
#   return math.isfinite(val)
# <Axes: >
